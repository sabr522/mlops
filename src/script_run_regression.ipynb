# %%
# %run regression.py
# Out:
# Current working directory: C:\Users\sashe\mlops\src\outputs\2024-02-25\15-00-29
# <style type="text/css">
# #T_242fd_row10_col1, #T_242fd_row16_col1, #T_242fd_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_242fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_242fd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_242fd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_242fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_242fd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_242fd_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_242fd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_242fd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_242fd_row1_col1" class="data row1 col1" >price</td>
# ...
